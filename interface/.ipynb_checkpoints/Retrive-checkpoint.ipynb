# %% [markdown]
# # Interface

# %%
from searcher import XQueryer

"""
Contributors : Bin Cao
================================================================
    Please feel free to open issues in the Github :
    https://github.com/Bin-Cao/XQueryer
    or
    contact Mr.Bin Cao (bcao686@connect.hkust-gz.edu.cn)
    in case of any problems/comments/suggestions in using the code.
==================================================================
:param api_key, type=str, required=True,
    Your Materials Project API key. see here : https://next-gen.materialsproject.org/api

:param Top_num, type=int, default=5,
    The number of top predicted materials to be retrieved.

:param XY_data_dir, type=str, default='./XY_data.csv',
    The directory of the XY data.   

:param Device, type=str, default='cuda:0',
    Which device to run the XQueryer, example: 'cuda:0', 'cpu'.

:param Load_path, type=str, default='./pretrained/checkpoint.pth' 

:param ElementsSystem, type=list, desfault=[]
    Specifies the elements to be included at least in the prediction, example: ['Fe'].


"""
Load_path_1='./pretrained/checkpoint_minnoise.pth'
Load_path_2='./pretrained/checkpoint_midnoise.pth'
api_key="O0EZBVkFbdM1Lcjg94q4TBPPmNkQKB8E"  # the MP api_key
XQueryer(api_key,Top_num = 1, Load_path=Load_path_1, XY_data_dir='./data/Pb2SO4.csv',ElementsSystem=['Al','Ni','O'])
# Out:
# Loaded model from ./pretrained/checkpoint_minnoise.pth
# Loaded data from: ['./infere/infere.db']
# C:\Users\binja\anaconda3\Lib\site-packages\torch\amp\autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# The MP link is :  https://next-gen.materialsproject.org/materials/mp-1220658
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Top 1 predicted materials:
# 1. mp-1220658 - Pb3(SO6)2 - O-Pb-S
# Full Formula (Pb12 S8 O48)
# Reduced Formula: Pb3(SO6)2
# abc   :   6.985205   8.534946  16.120259
# angles:  90.000000  90.000000  90.000000
# pbc   :       True       True       True
# Sites (68)
#   #  SP           a         b         c    magmom
# ---  ----  --------  --------  --------  --------
#   0  Pb    0.08887   0.691084  0.922811     0.019
#   1  Pb    0.082084  0.689883  0.247996     0.008
#   2  Pb    0.08272   0.682506  0.579101     0.017
#   3  Pb    0.91728   0.182506  0.920899     0.017
#   4  Pb    0.917916  0.189883  0.252004     0.008
#   5  Pb    0.91113   0.191084  0.577189     0.019
#   6  Pb    0.41728   0.317494  0.079101     0.017
#   7  Pb    0.41113   0.308916  0.422811     0.019
#   8  Pb    0.417916  0.310117  0.747996     0.008
#   9  Pb    0.58887   0.808916  0.077189     0.019
#  10  Pb    0.58272   0.817494  0.420899     0.017
#  11  Pb    0.582084  0.810117  0.752004     0.008
#  12  S     0.066556  0.938548  0.416902     0
#  13  S     0.06512   0.938843  0.749466     0.001
#  14  S     0.933444  0.438548  0.083098     0
#  15  S     0.93488   0.438843  0.750534     0.001
#  16  S     0.433444  0.061452  0.916902     0
#  17  S     0.43488   0.061157  0.249466     0.001
#  18  S     0.56512   0.561157  0.250534     0.001
#  19  S     0.566556  0.561452  0.583098     0
#  20  O     0.955335  0.920913  0.150154     1.194
#  21  O     0.939191  0.918105  0.491703     0.014
#  22  O     0.94223   0.917869  0.826275     0.014
#  23  O     0.060809  0.418105  0.008297     0.014
#  24  O     0.044665  0.420913  0.349846     1.194
#  25  O     0.05777   0.417869  0.673725     0.014
#  26  O     0.560809  0.081895  0.991703     0.014
#  27  O     0.55777   0.082131  0.326275     0.014
#  28  O     0.544665  0.079087  0.650154     1.194
#  29  O     0.455335  0.579087  0.849846     1.194
#  30  O     0.44223   0.582131  0.173725     0.014
#  31  O     0.439191  0.581895  0.508297     0.014
#  32  O     0.55589   0.084256  0.840937     0.011
#  33  O     0.560208  0.08129   0.174718     0.013
#  34  O     0.548301  0.079909  0.514588     1.098
#  35  O     0.451699  0.579909  0.985412     1.098
#  36  O     0.439792  0.58129   0.325282     0.013
#  37  O     0.44411   0.584256  0.659063     0.011
#  38  O     0.951699  0.920091  0.014588     1.098
#  39  O     0.94411   0.915744  0.340937     0.011
#  40  O     0.939792  0.91871   0.674718     0.013
#  41  O     0.05589   0.415744  0.159063     0.011
#  42  O     0.048301  0.420091  0.485412     1.098
#  43  O     0.060208  0.41871   0.825282     0.013
#  44  O     0.195311  0.833367  0.08243      1.257
#  45  O     0.214856  0.813259  0.41915      0.012
#  46  O     0.213153  0.812425  0.748911     0.013
#  47  O     0.785144  0.313259  0.08085      0.012
#  48  O     0.804689  0.333367  0.41757      1.257
#  49  O     0.786847  0.312425  0.751089     0.013
#  50  O     0.285144  0.186741  0.91915      0.012
#  51  O     0.286847  0.187575  0.248911     0.013
#  52  O     0.304689  0.166633  0.58243      1.257
#  53  O     0.695311  0.666633  0.91757      1.257
#  54  O     0.713153  0.687575  0.251089     0.013
#  55  O     0.714856  0.686741  0.58085      0.012
#  56  O     0.136187  0.070474  0.083252     1.345
#  57  O     0.145737  0.098123  0.416421     0.01
#  58  O     0.14752   0.097488  0.750749     0.008
#  59  O     0.854263  0.598123  0.083579     0.01
#  60  O     0.863813  0.570474  0.416748     1.345
#  61  O     0.85248   0.597488  0.749251     0.008
#  62  O     0.354263  0.901877  0.916421     0.01
#  63  O     0.35248   0.902512  0.250749     0.008
#  64  O     0.363813  0.929526  0.583252     1.345
#  65  O     0.636187  0.429526  0.916748     1.345
#  66  O     0.64752   0.402512  0.249251     0.008
#  67  O     0.645737  0.401877  0.583579     0.01
# [[MPDataDoc<SummaryDoc>(
#   builder_meta=EmmetMeta(emmet_version='0.72.20', pymatgen_version='2023.11.12', run_id=None, database_version='2023.11.1', build_date=datetime.datetime(2023, 11, 22, 19, 44, 58, 919000), license='BY-C'),
#   nsites=68,
#   elements=[Element O, Element Pb, Element S],
#   nelements=3,
#   composition=Composition('Pb12 S8 O48'),
#   composition_reduced=Composition('Pb3 S2 O12'),
#   formula_pretty='Pb3(SO6)2',
#   formula_anonymous='A2B3C12',
#   chemsys='O-Pb-S',
#   volume=961.0632024317473,
#   density=6.06616919826996,
#   density_atomic=14.133282388702167,
#   symmetry=SymmetryData(crystal_system=<CrystalSystem.ortho: 'Orthorhombic'>, symbol='P2_12_12_1', number=19, point_group='222', symprec=0.1, angle_tolerance=None, version='2.0.2'),
#   property_name='summary',
#   material_id=MPID(mp-1220658),
#   deprecated=False,
#   deprecation_reasons=None,
#   last_updated=datetime.datetime(2023, 11, 22, 19, 44, 58, 919000),
#   origins=[PropertyOrigin(name='structure', task_id=MPID(mp-1849863), last_updated=datetime.datetime(2021, 2, 5, 5, 16, 9, 718000)), PropertyOrigin(name='energy', task_id=MPID(mp-1849863), last_updated=datetime.datetime(2023, 8, 3, 19, 12, 42, 240000)), PropertyOrigin(name='electronic_structure', task_id=MPID(mp-1849863), last_updated=datetime.datetime(2021, 2, 5, 5, 16, 9, 718000)), PropertyOrigin(name='magnetism', task_id=MPID(mp-1849863), last_updated=datetime.datetime(2021, 2, 5, 5, 16, 9, 718000))],
#   warnings=[],
#   structure=Structure Summary
#   Lattice
#       abc : 6.985205 8.534946 16.120259
#    angles : 90.0 90.0 90.0
#    volume : 961.0632024317473
#         A : 6.985205 0.0 0.0
#         B : 0.0 8.534946 0.0
#         C : 0.0 0.0 16.120259
#       pbc : True True True
#   PeriodicSite: Pb (0.6208, 5.898, 14.88) [0.08887, 0.6911, 0.9228]
#   PeriodicSite: Pb (0.5734, 5.888, 3.998) [0.08208, 0.6899, 0.248]
#   PeriodicSite: Pb (0.5778, 5.825, 9.335) [0.08272, 0.6825, 0.5791]
#   PeriodicSite: Pb (6.407, 1.558, 14.85) [0.9173, 0.1825, 0.9209]
#   PeriodicSite: Pb (6.412, 1.621, 4.062) [0.9179, 0.1899, 0.252]
#   PeriodicSite: Pb (6.364, 1.631, 9.304) [0.9111, 0.1911, 0.5772]
#   PeriodicSite: Pb (2.915, 2.71, 1.275) [0.4173, 0.3175, 0.0791]
#   PeriodicSite: Pb (2.872, 2.637, 6.816) [0.4111, 0.3089, 0.4228]
#   PeriodicSite: Pb (2.919, 2.647, 12.06) [0.4179, 0.3101, 0.748]
#   PeriodicSite: Pb (4.113, 6.904, 1.244) [0.5889, 0.8089, 0.07719]
#   PeriodicSite: Pb (4.07, 6.977, 6.785) [0.5827, 0.8175, 0.4209]
#   PeriodicSite: Pb (4.066, 6.914, 12.12) [0.5821, 0.8101, 0.752]
#   PeriodicSite: S (0.4649, 8.01, 6.721) [0.06656, 0.9385, 0.4169]
#   PeriodicSite: S (0.4549, 8.013, 12.08) [0.06512, 0.9388, 0.7495]
#   PeriodicSite: S (6.52, 3.743, 1.34) [0.9334, 0.4385, 0.0831]
#   PeriodicSite: S (6.53, 3.746, 12.1) [0.9349, 0.4388, 0.7505]
#   PeriodicSite: S (3.028, 0.5245, 14.78) [0.4334, 0.06145, 0.9169]
#   PeriodicSite: S (3.038, 0.522, 4.021) [0.4349, 0.06116, 0.2495]
#   PeriodicSite: S (3.947, 4.789, 4.039) [0.5651, 0.5612, 0.2505]
#   PeriodicSite: S (3.958, 4.792, 9.4) [0.5666, 0.5615, 0.5831]
#   PeriodicSite: O (6.673, 7.86, 2.421) [0.9553, 0.9209, 0.1502]
#   PeriodicSite: O (6.56, 7.836, 7.926) [0.9392, 0.9181, 0.4917]
#   PeriodicSite: O (6.582, 7.834, 13.32) [0.9422, 0.9179, 0.8263]
#   PeriodicSite: O (0.4248, 3.569, 0.1337) [0.06081, 0.4181, 0.008297]
#   PeriodicSite: O (0.312, 3.592, 5.64) [0.04467, 0.4209, 0.3498]
#   PeriodicSite: O (0.4035, 3.566, 10.86) [0.05777, 0.4179, 0.6737]
#   PeriodicSite: O (3.917, 0.699, 15.99) [0.5608, 0.08189, 0.9917]
#   PeriodicSite: O (3.896, 0.701, 5.26) [0.5578, 0.08213, 0.3263]
#   PeriodicSite: O (3.805, 0.675, 10.48) [0.5447, 0.07909, 0.6502]
#   PeriodicSite: O (3.181, 4.942, 13.7) [0.4553, 0.5791, 0.8498]
#   PeriodicSite: O (3.089, 4.968, 2.8) [0.4422, 0.5821, 0.1737]
#   PeriodicSite: O (3.068, 4.966, 8.194) [0.4392, 0.5819, 0.5083]
#   PeriodicSite: O (3.883, 0.7191, 13.56) [0.5559, 0.08426, 0.8409]
#   PeriodicSite: O (3.913, 0.6938, 2.816) [0.5602, 0.08129, 0.1747]
#   PeriodicSite: O (3.83, 0.682, 8.295) [0.5483, 0.07991, 0.5146]
#   PeriodicSite: O (3.155, 4.949, 15.89) [0.4517, 0.5799, 0.9854]
#   PeriodicSite: O (3.072, 4.961, 5.244) [0.4398, 0.5813, 0.3253]
#   PeriodicSite: O (3.102, 4.987, 10.62) [0.4441, 0.5843, 0.6591]
#   PeriodicSite: O (6.648, 7.853, 0.2352) [0.9517, 0.9201, 0.01459]
#   PeriodicSite: O (6.595, 7.816, 5.496) [0.9441, 0.9157, 0.3409]
#   PeriodicSite: O (6.565, 7.841, 10.88) [0.9398, 0.9187, 0.6747]
#   PeriodicSite: O (0.3904, 3.548, 2.564) [0.05589, 0.4157, 0.1591]
#   PeriodicSite: O (0.3374, 3.585, 7.825) [0.0483, 0.4201, 0.4854]
#   PeriodicSite: O (0.4206, 3.574, 13.3) [0.06021, 0.4187, 0.8253]
#   PeriodicSite: O (1.364, 7.113, 1.329) [0.1953, 0.8334, 0.08243]
#   PeriodicSite: O (1.501, 6.941, 6.757) [0.2149, 0.8133, 0.4192]
#   PeriodicSite: O (1.489, 6.934, 12.07) [0.2132, 0.8124, 0.7489]
#   PeriodicSite: O (5.484, 2.674, 1.303) [0.7851, 0.3133, 0.08085]
#   PeriodicSite: O (5.621, 2.845, 6.731) [0.8047, 0.3334, 0.4176]
#   PeriodicSite: O (5.496, 2.667, 12.11) [0.7868, 0.3124, 0.7511]
#   PeriodicSite: O (1.992, 1.594, 14.82) [0.2851, 0.1867, 0.9192]
#   PeriodicSite: O (2.004, 1.601, 4.013) [0.2868, 0.1876, 0.2489]
#   PeriodicSite: O (2.128, 1.422, 9.389) [0.3047, 0.1666, 0.5824]
#   PeriodicSite: O (4.857, 5.69, 14.79) [0.6953, 0.6666, 0.9176]
#   PeriodicSite: O (4.982, 5.868, 4.048) [0.7132, 0.6876, 0.2511]
#   PeriodicSite: O (4.993, 5.861, 9.363) [0.7149, 0.6867, 0.5808]
#   PeriodicSite: O (0.9513, 0.6015, 1.342) [0.1362, 0.07047, 0.08325]
#   PeriodicSite: O (1.018, 0.8375, 6.713) [0.1457, 0.09812, 0.4164]
#   PeriodicSite: O (1.03, 0.8321, 12.1) [0.1475, 0.09749, 0.7507]
#   PeriodicSite: O (5.967, 5.105, 1.347) [0.8543, 0.5981, 0.08358]
#   PeriodicSite: O (6.034, 4.869, 6.718) [0.8638, 0.5705, 0.4167]
#   PeriodicSite: O (5.955, 5.1, 12.08) [0.8525, 0.5975, 0.7493]
#   PeriodicSite: O (2.475, 7.697, 14.77) [0.3543, 0.9019, 0.9164]
#   PeriodicSite: O (2.462, 7.703, 4.042) [0.3525, 0.9025, 0.2507]
#   PeriodicSite: O (2.541, 7.933, 9.402) [0.3638, 0.9295, 0.5833]
#   PeriodicSite: O (4.444, 3.666, 14.78) [0.6362, 0.4295, 0.9167]
#   PeriodicSite: O (4.523, 3.435, 4.018) [0.6475, 0.4025, 0.2493]
#   PeriodicSite: O (4.511, 3.43, 9.407) [0.6457, 0.4019, 0.5836],
#   task_ids=[MPID(mp-1220658), MPID(mp-1325419), MPID(mp-1849863)],
#   uncorrected_energy_per_atom=-5.425381145,
#   energy_per_atom=-5.910322321470589,
#   formation_energy_per_atom=-1.272567908823529,
#   energy_above_hull=0.2712693079411759,
#   is_stable=False,
#   equilibrium_reaction_energy_per_atom=None,
#   decomposes_to=[DecompositionProduct(material_id=MPID(mp-20725), formula='Pb2 O4', amount=0.17647058823529393), DecompositionProduct(material_id=MPID(mp-623984), formula='Pb4 S4 O16', amount=0.7058823529411764), DecompositionProduct(material_id=MPID(mp-611836), formula='O2', amount=0.11764705882352988)],
#   xas=None,
#   grain_boundaries=None,
#   band_gap=1.1614000000000004,
#   cbm=4.0113,
#   vbm=2.8499,
#   efermi=4.01121232,
#   is_gap_direct=True,
#   is_metal=False,
#   es_source_calc_id=None,
#   bandstructure=None,
#   dos=None,
#   dos_energy_up=None,
#   dos_energy_down=None,
#   is_magnetic=True,
#   ordering='FM',
#   total_magnetization=24.0157427,
#   total_magnetization_normalized_vol=0.024988723571180062,
#   total_magnetization_normalized_formula_units=6.003935675,
#   num_magnetic_sites=16,
#   num_unique_magnetic_sites=12,
#   types_of_magnetic_species=[Element O],
#   bulk_modulus=None,
#   shear_modulus=None,
#   universal_anisotropy=None,
#   homogeneous_poisson=None,
#   e_total=None,
#   e_ionic=None,
#   e_electronic=None,
#   n=None,
#   e_ij_max=None,
#   weighted_surface_energy_EV_PER_ANG2=None,
#   weighted_surface_energy=None,
#   weighted_work_function=None,
#   surface_anisotropy=None,
#   shape_factor=None,
#   has_reconstructed=None,
#   possible_species=['Pb4+', 'O2-', 'S6+'],
#   has_props={'materials': True, 'thermo': True, 'xas': False, 'grain_boundaries': False, 'chemenv': True, 'electronic_structure': True, 'absorption': False, 'bandstructure': False, 'dos': False, 'magnetism': True, 'elasticity': False, 'dielectric': False, 'piezoelectric': False, 'surface_properties': False, 'oxi_states': True, 'provenance': True, 'charge_density': True, 'eos': False, 'phonon': False, 'insertion_electrodes': False, 'substrates': False},
#   theoretical=True,
#   database_IDs={},
#   fields_not_requested=[]
#   )]]
