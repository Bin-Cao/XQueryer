# %%
from mp_api.client import MPRester

with MPRester(api_key="O0EZBVkFbdM1Lcjg94q4TBPPmNkQKB8E") as mpr:
    # retrieve SummaryDocs for a list of materials
    docs = mpr.summary.search(material_ids=["mp-861872"])
# Out:
# /var/folders/jc/tqqw6tl5213fpq5xm6rjh78r0000gn/T/ipykernel_52106/634234338.py:5: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   docs = mpr.summary.search(material_ids=["mp-861872"])
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
docs
# Out:
# [MPDataDoc<SummaryDoc>(
#  builder_meta=EmmetMeta(emmet_version='0.72.20', pymatgen_version='2023.11.12', run_id=None, database_version='2023.11.1', build_date=datetime.datetime(2023, 11, 22, 19, 50, 43, 512000), license='BY-C'),
#  nsites=4,
#  elements=[Element Ac, Element Ge, Element Hg],
#  nelements=3,
#  composition=Composition('Ac2 Hg1 Ge1'),
#  composition_reduced=Composition('Ac2 Hg1 Ge1'),
#  formula_pretty='Ac2HgGe',
#  formula_anonymous='ABC2',
#  chemsys='Ac-Ge-Hg',
#  volume=124.86821324902324,
#  density=9.670946624304037,
#  density_atomic=31.21705331225581,
#  symmetry=SymmetryData(crystal_system=<CrystalSystem.cubic: 'Cubic'>, symbol='Fm-3m', number=225, point_group='m-3m', symprec=0.1, version='2.0.2'),
#  property_name='summary',
#  material_id=MPID(mp-861872),
#  deprecated=False,
#  deprecation_reasons=None,
#  last_updated=datetime.datetime(2023, 11, 22, 19, 50, 43, 512000),
# ...

# %%
pip install mp-api
# Out:
# ...
#   Using cached mp_api-0.41.2-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached mp_api-0.41.2-py3-none-any.whl (97 kB)
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 测试 inference code

# %%
from searcher import XQueryer

api_key="O0EZBVkFbdM1Lcjg94q4TBPPmNkQKB8E" 
XQueryer(api_key,XY_data_dir='XY.csv',ElementsSystem=['Pb','S','O'])
# Out:
# Loaded model from ./pretrained/checkpoint_0010.pth
# Loaded data from: ['./infere/infere.db']
# Evaluating... :   0%|                                   | 0/1 [00:00<?, ?data/s]/Users/jacob/miniconda3/lib/python3.9/site-packages/transformers/utils/generic.py:485: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /Users/jacob/miniconda3/lib/python3.9/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# ...
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# [MPDataDoc<SummaryDoc>(
# builder_meta=EmmetMeta(emmet_version='0.72.20', pymatgen_version='2023.11.12', run_id=None, database_version='2023.11.1', build_date=datetime.datetime(2023, 11, 22, 19, 47, 33, 968000), license='BY-C'),
# nsites=28,
# ...

# %%
import pandas as pd

df = pd.read_csv('XY.txt', sep='\s+', skiprows=1, usecols=[0, 1], header=None)

# %%
df
# Out:
#                         0      1
# 0                 10.025,  147.0
# 1                  10.05,  165.0
# 2     10.075000000000001,  172.0
# 3     10.100000000000001,  150.0
# 4     10.125000000000002,  165.0
# ...                   ...    ...
# 5995  159.90000000000214,  420.0
# 5996  159.92500000000214,  374.0
# 5997  159.95000000000212,  352.0
# 5998  159.97500000000213,  328.0
# 5999  160.00000000000213,  368.0
#
# [6000 rows x 2 columns]
